# %% [markdown]
# JB20_085_DM 粒線體資料清理

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('JB20_085_DM.csv')

# %%
df.head(10)
# Out:
#   #CHROM   POS           ID  REF     ALT      QUAL FILTER  \
# 0   chrM   195            .    C       T  15498.77      .
# 1   chrM   199   rs72619362    T       C  10165.77      .
# 2   chrM   302  rs878871521    A  AC,ACC   1070.73      .
# 3   chrM   410            .    A       T   4897.77      .
# 4   chrM   491            .    T       C   9527.77      .
# 5   chrM   515            .  GCA       G  14824.73      .
# 6   chrM  2354            .    C       T  36833.77      .
# 7   chrM  2485            .    C       T  41702.73      .
# 8   chrM  4049            .    G       A   1389.03      .
# 9   chrM  4072            .    C       T   1474.77      .
#
#                                                 INFO          FORMAT  \
# 0  AC=2;AF=1.00;AN=2;DP=361;ExcessHet=3.0103;FS=0...  GT:AD:DP:GQ:PL
# 1  AC=2;AF=1.00;AN=2;BaseQRankSum=3.439;ClippingR...  GT:AD:DP:GQ:PL
# 2  AC=1,1;AF=0.500,0.500;AN=2;BaseQRankSum=0.790;...  GT:AD:DP:GQ:PL
# ...

# %%
df.shape
# Out:
# (80117, 10)

# %%
df['GT'],df['AD'],df['DP'],df['GQ'],df['PL'] = df['JB20_085'].str.split(':').str
# Out:
# <ipython-input-34-e29467981546>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df['GT'],df['AD'],df['DP'],df['GQ'],df['PL'] = df['JB20_085'].str.split(':').str

# %%
df.head(10)
# Out:
#   #CHROM   POS           ID  REF     ALT      QUAL FILTER  \
# 0   chrM   195            .    C       T  15498.77      .
# 1   chrM   199   rs72619362    T       C  10165.77      .
# 2   chrM   302  rs878871521    A  AC,ACC   1070.73      .
# 3   chrM   410            .    A       T   4897.77      .
# 4   chrM   491            .    T       C   9527.77      .
# 5   chrM   515            .  GCA       G  14824.73      .
# 6   chrM  2354            .    C       T  36833.77      .
# 7   chrM  2485            .    C       T  41702.73      .
# 8   chrM  4049            .    G       A   1389.03      .
# 9   chrM  4072            .    C       T   1474.77      .
#
#                                                 INFO          FORMAT  \
# 0  AC=2;AF=1.00;AN=2;DP=361;ExcessHet=3.0103;FS=0...  GT:AD:DP:GQ:PL
# 1  AC=2;AF=1.00;AN=2;BaseQRankSum=3.439;ClippingR...  GT:AD:DP:GQ:PL
# 2  AC=1,1;AF=0.500,0.500;AN=2;BaseQRankSum=0.790;...  GT:AD:DP:GQ:PL
# ...
